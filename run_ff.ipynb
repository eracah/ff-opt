# %%
from ff import ff_opt

# %%
a=ff_opt(QB=2, RB=2, WR=3, TE=1, DST=1, Budget=178,process_keepers=False)

# %%
b=a.run_opt()
# Out:
#    pos              player price max_price  score_dropoff
# 0   QB       CalebWilliams    $9       $14            4.9
# 1   QB       DeshaunWatson    $8        $9            1.0
# 2   RB  ChristianMcCaffrey   $58       $74           30.0
# 3   RB        DerrickHenry   $23       $28            2.9
# 4   TE         MarkAndrews    $7       $12            2.9
# 5   WR          TyreekHill   $48       $53            3.7
# 6   WR         NicoCollins   $13       $14            0.2
# 7   WR       DeeboSamuelSr   $11       $12            1.7
# 8  DST             Cowboys    $0        $1            1.7
#
# Total Points of this Lineup: 2060.700
# My Points Would Be: 2060.700
# Budget: 178

# %%
a.wr()
# Out:
#                player  price  max_price_id_pay_rn
# 112        CeeDeeLamb     57                   53
# 113        TyreekHill     48                   53
# 114      Ja'MarrChase     44                   38
# 115    Amon-RaStBrown     46                   37
# 116   JustinJefferson     43                   35
# 117         PukaNacua     36                   27
# 118           AJBrown     37                   27
# 119     GarrettWilson     35                   22
# 120        ChrisOlave     28                   18
# 121  MarvinHarrisonJr     17                   18
# 122         MikeEvans     25                   12
# 123       NicoCollins     13                   12
# 124       DrakeLondon     14                   12
# 125     DeeboSamuelSr     11                   12
# 126      DavanteAdams     26                   10
# 127      BrandonAiyuk     10                    8
# 128        CooperKupp      9                    8
# 129      DeVontaSmith     10                    8
# ...

# %%
a.ig('',1)
# Out:
# i got  Cowboys
#   pos       player price max_price  score_dropoff
# 0  RB  JamesConner   $12       $18           11.1
#
# Total Points of this Lineup: 187.600
# My Points Would Be: 1511.100
# Budget: 18

# %%
a.rb()
# Out:
#          player  price  max_price_id_pay_rn
# 45  JamesConner     12                   15

# %%
a.run_opt()
# Out:
#   pos         player price max_price  score_dropoff
# 0  RB    JamesConner   $12       $15            9.5
# 1  WR  ChristianKirk    $4        $7            3.0
#
# Total Points of this Lineup: 354.300
# My Points Would Be: 1563.300
# Budget: 19
# ([('JamesConner', 12.0, 'RB'), ('ChristianKirk', 4.0, 'WR')],
#  354.29999999999995,
#  1563.3)

# %%
a.witg('JamesConner')
# Out:
#   pos        player price max_price  score_dropoff
# 0  RB     JKDobbins    $5        $4           -9.5
# 1  WR  MikeWilliams    $9        $8           -9.5
#
# Total Points of this Lineup: 344.800
# My Points Would Be: 1553.800
# Budget: 19
# what if they got:  JamesConner
# My proj points would be: 1553.8
# 1553.8

# %%
a.wr()
# Out:
#             player  price  max_price_id_pay_rn
# 138   MikeWilliams      9                    7
# 140  TerryMcLaurin      9                    7
# 141  ChristianKirk      4                    7

# %%
a.rb()
# Out:
#           player  price  max_price_id_pay_rn
# 53  IsiahPacheco      5                    6

# %%
a.tg('IsiahPacheco')
# Out:
# they got:  IsiahPacheco
#   pos         player price max_price  score_dropoff
# 0  RB  RaheemMostert    $2        $6            1.5
#
# Total Points of this Lineup: 147.900
# My Points Would Be: 1525.300
# Budget: 6

# %%
a.ig('BrianRobinsonjr',2)
# Out:
# i got  BrianRobinsonjr
# That player ain't even an option

# %%
a.min_i_could_pay_for('DalvinCook')
# Out:
# 0

# %%
a.tg('ZayFlowers')
# Out:
# they got:  ZayFlowers
#   pos            player price max_price  score_dropoff
# 0  RB      DamienHarris    $0        $0            0.3
# 1  TE  ChigoziemOkonkwo    $1        $1            0.6
# 2  WR       DrakeLondon    $6        $6            0.6
# 3  WR          ZayJones    $0        $1            7.5
# 4  WR        RomeoDoubs    $0        $0            2.8
#
# Total Points of this Lineup: 581.600
# My Points Would Be: 2650.600
# Budget: 7

# %%
a.ig('GeorgePickens', 1)
# Out:
# i got  GeorgePickens
# That player ain't even an option

# %%
a.bench_opt(total_budget=206)
# Out:
# processing keepers...
# 	 * DerrickHenry
# 	 * JoshAllen
# 	 * DavanteAdams
# 	 * MarkAndrews
# After keepers optimal lineup to draft is:
#
#    pos           player price max_price  score_dropoff
# 0   QB      DakPrescott    $2        $2            2.0
# 1   RB        JKDobbins    $5        $8           11.5
# 2   RB     IsiahPacheco    $5        $6            6.2
# 3   RB  DavidMontgomery    $5        $5            3.8
# 4   TE     GeorgeKittle    $6        $7            5.9
# 5   WR     MikeWilliams    $9        $9            1.8
# 6   WR        MikeEvans    $9        $9            1.2
# 7   WR    ChristianKirk    $4        $7           14.8
# 8   WR      DrakeLondon    $6        $6            2.1
# 9   WR      JahanDotson    $4        $4            1.2
# 10  WR        GabeDavis    $2        $2            3.3
#
# Total Points of this Lineup: 1893.600
# My Points Would Be: 2874.600
# Budget: 57
# resoring from file...
# they got:  BijanRobinson
# ...
